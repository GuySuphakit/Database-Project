# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from glob import glob

# conda install sqlalchemy, psycopg2
from sqlalchemy import create_engine

# pip install psycopg2-binary -U
import psycopg2

from tqdm import tqdm, trange

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
# %load_ext sql

import getpass
from sqlalchemy import create_engine
host='localhost'
# host='vdi-t34.acc.chula.ac.th'
port=5432

user=getpass.getpass('user: ')
pwd=getpass.getpass('password: ')

# create connection to yummi
dbname='yummi2'
connection_string=f'postgresql+psycopg2://{user}:{pwd}@{host}:{port}/{dbname}' # for %sql magic
# %sql $connection_string
con1=create_engine(connection_string) # for sqlalchemy

# create connection to disney
# dbname='disney'
# connection_string=f'postgresql+psycopg2://{user}:{pwd}@{host}:{port}/{dbname}' # for %sql magic
# %sql $connection_string

# %config SqlMagic.autopandas = True

# con2=create_engine(connection_string) # for sqlalchemy

# con=con1
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# user:  ········
# password:  ·············

# %%
# %sql postgres@yummi2

# %%
# %%sql
# drop database if exists yummi2;
# create database yummi2 with template yummi;

# %%
# %%sql
# select * from menu
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 19 rows affected.
#    menuid                     descr           descrth sizeid categoryid  \
# 0   201L6      Tom Yum Kung (Large)  ต้มยำกุ้ง (ใหญ่)      L         DI
# 1   201M7     Tom Yum Kung (Medium)  ต้มยำกุ้ง (กลาง)      M         DI
# 2   201S3      Tom Yum Kung (Small)  ต้มยำกุ้ง (เล็ก)      S         DI
# 3   202M9  Green Curry with Chicken   แกงเขียวหวานไก่      M         DI
# 4   203M1              Pla Rad Prik        ปลาราดพริก      L         DI
# 5   204L2           Mixed Vegetable         ผัดผักรวม      L         DI
# 6   205M5             Fried Chicken            ไก่ทอด      M         DI
# 7   101S9                 Fish Cake         ทอดมันปลา      S         AP
# 8   102S1                   Tempura           เทมปุระ      S         AP
# 9   103S3                Pork Satay         หมูสะเต็ะ      S         AP
# ...

# %%
# %%sql
# update menu
#     set price=25,
#         cost=12
#     where menuid='302M3';
# update menu
#     set margin=price-cost
#     where menuid='302M3';
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 1 rows affected.
# 1 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select * from orderhdr limit 5
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 5 rows affected.
#    orderid customerid  noguest  tableno              intime  \
# 0        1        PH1        4        5 2002-01-01 10:51:00
# 1        2        ZF1        1        3 2002-01-01 11:35:00
# 2        3        ZF1        2        1 2002-01-01 12:14:00
# 3        4        ZF1        3        5 2002-01-01 18:59:00
# 4        5        ZF1        1        5 2002-01-02 11:58:00
#
#               outtime dinetypeid paymentid    total discount   netpay    vat  \
# 0 2002-01-01 12:00:00         EI      CASH  1300.00   187.50  1112.50  72.78
# 1 2002-01-01 12:42:00         EI      CASH   675.00     0.00   675.00  44.16
# 2 2002-01-01 14:33:00         EI       CHK   520.00     0.00   520.00  34.02
# 3 2002-01-01 19:58:00         EI        MC   490.00    19.50   470.50  30.78
# 4 2002-01-02 13:32:00         EI      CASH   480.00     0.00   480.00  31.40
#
# ...

# %%
# %%sql
# select orderid, sum(a.qty*price) amt
# from ordermenudtl a inner join menu m using(menuid)
# group by orderid limit 5
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 5 rows affected.
#    orderid   amt
# 0        1  1300
# 1        2   675
# 2        3   520
# 3        4   490
# 4        5   480

# %%
# %%sql
# select orderid, sum(a.qty*price) amt
# into orderamt
# from ordermenudtl a inner join menu m using(menuid)
# group by orderid
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 5000 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# update orderhdr set total = 0
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 5000 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# update orderhdr
# set total=orderamt.amt
# from orderamt where orderhdr.orderid=orderamt.orderid
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 5000 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ```
# p_id,name,name_en,region,area_km2
# กจ,กาญจนบุรี,kanchanaburi,C,19483.148
# กทม,กรุงเทพมหานคร,Bangkok,C,1568.737
# ```

# %%
# %%sql
# drop table if exists province;
# create table province(
#     p_id varchar(3),
#     name varchar(15),
#     name_en varchar(24),
#     region varchar(2),
#     area_km2 real
# );
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# Done.
# Done.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# select * from province
# Out:
#    postgresql+psycopg2://postgres:***@localhost:5432/yummi
#  * postgresql+psycopg2://postgres:***@localhost:5432/yummi2
# 0 rows affected.
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# \copy public.province(p_id,name,name_en,region,area_km2) 
# from '/Users/jackie/446/sql/province.csv'
# DELIMITER ',' csv HEADER QUOTE '"';

# %%
โปรเจค เลือกธุรกิจมา 1 อย่าง design จามสแควร์กับสามย่านมิตทาวน์
